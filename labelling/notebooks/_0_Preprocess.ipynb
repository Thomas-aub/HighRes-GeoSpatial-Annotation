# %%
import sys
import os

# Add the project root (one level up) to sys.path
# This allows you to import from 'src' as a top-level package
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Now import using the full package path, consistent with your internal code
from src.data_preparation.tiling import tile_raster

# %%
# Tiling 
from src.utils.file_utils import slice_raster

tile_raster(
    raster_in_path=  "/home/thomas/Documents/thomas/HighRes-GeoSpatial-Annotation/labelling/data/Nosy_boraha_north.tif",
    raster_out_dir = "/home/thomas/Documents/thomas/HighRes-GeoSpatial-Annotation/labelling/data/north/raw",
    tile_size = 1024,
    skip_empty_tiles = True
)
