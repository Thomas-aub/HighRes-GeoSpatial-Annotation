# %%
import sys
import os

# Add the project root (one level up) to sys.path
# This allows you to import from 'src' as a top-level package
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# Prediction 
from src.modeling.model import run_batch_inference

run_batch_inference(
    dir_tiles="/home/thomas/Documents/thomas/HighRes-GeoSpatial-Annotation/labelling/data/north/raw",
    output_geojson="/home/thomas/Documents/thomas/HighRes-GeoSpatial-Annotation/labelling/results/north/raw/boats_north.geojson",
    prompts="boats",
    model_path="/home/thomas/Documents/thomas/HighRes-GeoSpatial-Annotation/labelling/assets/sam3.pt",
)

"""
PROMPTS = [
    "Solid elongated floating on water",        # Faux positifs
    "Thin linear shapes on the sea surface",    # Faux positifs
    "Dark wooden pirogues at sea",              # Faux positifs
    "Dark wooden pirogues beached on sand",     # Faux positifs
    "Rigid boat hulls on water",                # Bien 
    "Small elongated objects on water",         # Bien 
    "Elongated vessel shapes in water",         # Bien 
    "Boat",                                     # Test
    "Waves"                                     # Test

]
"""
# Out:
# Found 576 tiles to process...
# Processing: Nosy_boraha_north_0_11264.tif
#   - Running inference for prompt: 'b'
# Ultralytics 8.4.1 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4080, 15946MiB)
# WARNING ⚠️ imgsz=[1024] must be multiple of max stride 14, updating to [1036]
#
# image 1/1 /home/thomas/Documents/thomas/HighRes-GeoSpatial-Annotation/labelling/data/north/raw/Nosy_boraha_north_0_11264.tif: 1036x1036 (no detections), 45.2ms
# Speed: 2.3ms preprocess, 45.2ms inference, 0.2ms postprocess per image at shape (1, 3, 1036, 1036)
#   - Running inference for prompt: 'o'
# WARNING ⚠️ imgsz=[1024] must be multiple of max stride 14, updating to [1036]
#
# image 1/1 /home/thomas/Documents/thomas/HighRes-GeoSpatial-Annotation/labelling/data/north/raw/Nosy_boraha_north_0_11264.tif: 1036x1036 (no detections), 45.4ms
# Speed: 2.3ms preprocess, 45.4ms inference, 0.2ms postprocess per image at shape (1, 3, 1036, 1036)
#   - Running inference for prompt: 'a'
# ...
